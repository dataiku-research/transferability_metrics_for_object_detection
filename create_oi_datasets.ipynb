# %%
import fiftyone as fo
import fiftyone.utils.openimages as openimages
import random
import pandas as pd
import numpy as np

# %%
dataset = fo.zoo.load_zoo_dataset(
          "open-images-v6",
          split="validation", 
        download_if_necessary  =  True,  
      )
# Out:
# Downloading split 'validation' to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/validation' if necessary
# Downloading 'https://storage.googleapis.com/openimages/v6/oidv6-attributes-description.csv' to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/validation/metadata/attributes.csv'
# Downloading 'https://storage.googleapis.com/openimages/v5/classes-segmentation.txt' to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/validation/metadata/segmentation_classes.csv'
# Downloading 'https://storage.googleapis.com/openimages/v5/validation-annotations-human-imagelabels-boxable.csv' to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/validation/labels/classifications.csv'
# Downloading 'https://storage.googleapis.com/openimages/v6/oidv6-validation-annotations-vrd.csv' to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/validation/labels/relationships.csv'
# Downloading 'https://storage.googleapis.com/openimages/v5/validation-annotations-object-segmentation.csv' to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/validation/labels/segmentations.csv'
# Necessary images already downloaded
# Dataset info written to '/Users/louisfouquet/fiftyone/open-images-v6/Raw/info.json'
# Loading existing dataset 'open-images-v6-validation'. To reload from disk, either delete the existing dataset or provide a custom `dataset_name` to use

# %%
df = pd.read_csv('./fiftyone/open-images-v6/Raw/validation/labels/detections.csv').iloc[:,:3]
df_label = pd.read_csv('./fiftyone/open-images-v6/oidv7-class-descriptions.csv')
df_tot = pd.merge(df, df_label, left_on = 'LabelName', right_on = 'LabelName') #Merge LabelName and Display Name
df_tot = df_tot.drop(['Source'], axis = 1)
df_tot
# Out:
#                  ImageID  LabelName          DisplayName
# 0       0001eeaf4aed83f9   /m/0cmf2  Fixed-wing aircraft
# 1       0009bad4d8539bb4   /m/0cmf2  Fixed-wing aircraft
# 2       0019e544c79847f5   /m/0cmf2  Fixed-wing aircraft
# 3       0019e544c79847f5   /m/0cmf2  Fixed-wing aircraft
# 4       007384da2ed0464f   /m/0cmf2  Fixed-wing aircraft
# ...                  ...        ...                  ...
# 303975  ef11d2f491f7af3f   /m/05bm6  Nail (Construction)
# 303976  dea86ba2060f08c2   /m/0f571               Diaper
# 303977  f3e368998a146c69  /m/076lb9       Training bench
# 303978  f3e368998a146c69  /m/076lb9       Training bench
# 303979  f48fed4fa03acbca   /m/03l9g               Hammer
#
# [303980 rows x 3 columns]

# %%
#Create a pivot table with for each image the objects within
pivot = pd.pivot_table(df_tot, values = 'LabelName', index = 'ImageID', columns = 'DisplayName', aggfunc='count', fill_value = 0)
pivot = pivot.loc[:, np.sum(pivot > 0) > 200] # Filter classes  contained in more than 200 images
pivot
# Out:
# DisplayName       Animal  Auto part  Baked goods  Ball (Object)  Bicycle  \
# ImageID
# 0001eeaf4aed83f9       0          0            0              0        0
# 000595fe6fee6369       0          0            0              0        0
# 00075905539074f2       0          0            0              0        0
# 0007cebe1b2ba653       0          0            0              0        0
# 0007d6cf88afaa4a       0          0            0              0        0
# ...                  ...        ...          ...            ...      ...
# fff3ce694bc02a09       0          0            0              0        0
# fff50186c03c8474       0          0            0              0        0
# fff820866f567015       0          0            0              0        0
# fffc2f36b181a4fb       0          0            0              0        0
# ffff21932da3ed01       0          0            0              0        0
#
# DisplayName       Bicycle wheel  Bird  Boat  Bottle  Boy  ...  Toy  Tree  \
# ImageID                                                   ...
# 0001eeaf4aed83f9              0     0     0       0    0  ...    0     0
# 000595fe6fee6369              0     0     0       0    0  ...    0     0
# 00075905539074f2              0     0     0       0    0  ...    0     0
# 0007cebe1b2ba653              0     0     0       0    0  ...    0     0
# 0007d6cf88afaa4a              0     0     0       0    0  ...    0     0
# ...                         ...   ...   ...     ...  ...  ...  ...   ...
# fff3ce694bc02a09              0     0     0       0    0  ...    0     0
# fff50186c03c8474              0     0     0       0    0  ...    0     0
# fff820866f567015              0     0     0       0    0  ...    0     0
# fffc2f36b181a4fb              0     0     0       0    0  ...    0     0
# ffff21932da3ed01              0     0     0       0    0  ...    0     0
#
# DisplayName       Trousers  Truck  Vegetable  Vehicle  \
# ImageID
# 0001eeaf4aed83f9         0      0          0        0
# 000595fe6fee6369         0      0          0        0
# 00075905539074f2         0      0          0        0
# 0007cebe1b2ba653         1      0          0        0
# 0007d6cf88afaa4a         0      0          0        0
# ...                    ...    ...        ...      ...
# fff3ce694bc02a09         0      0          0        0
# fff50186c03c8474         0      0          0        0
# fff820866f567015         0      0          0        2
# fffc2f36b181a4fb         0      0          0        0
# ffff21932da3ed01         0      0          0        0
#
# DisplayName       Vehicle registration plate  Wheel  Window  Woman
# ImageID
# 0001eeaf4aed83f9                           0      0       0      0
# 000595fe6fee6369                           0      0       0      0
# 00075905539074f2                           0      0       0      0
# 0007cebe1b2ba653                           0      0       0      0
# 0007d6cf88afaa4a                           0      0       0      0
# ...                                      ...    ...     ...    ...
# fff3ce694bc02a09                           0      0       0      0
# fff50186c03c8474                           0      0       0      0
# fff820866f567015                           0      1       0      0
# fffc2f36b181a4fb                           0      0       0      0
# ffff21932da3ed01                           0      0       0      0
#
# [37306 rows x 75 columns]

# %%
#Compute the co-occurence matrix
cocc = pivot.T.dot(pivot)
np.fill_diagonal(cocc.values, 0)
cocc
# Out:
# DisplayName                 Animal  Auto part  Baked goods  Ball (Object)  \
# DisplayName
# Animal                           0          0            0              0
# Auto part                        0          0            0              0
# Baked goods                      0          0            0              0
# Ball (Object)                    0          0            0              0
# Bicycle                          0         22            0              1
# ...                            ...        ...          ...            ...
# Vehicle                          6        452            0             22
# Vehicle registration plate       0        680            0              0
# Wheel                           13       6956            0              4
# Window                           3       1789            0              0
# Woman                            5         49           83            145
#
# DisplayName                 Bicycle  Bicycle wheel  Bird  Boat  Bottle  Boy  \
# DisplayName
# Animal                            0              0    26     0       1    2
# Auto part                        22             30     0    35       0    2
# Baked goods                       0              0     0     0       4    1
# Ball (Object)                     1              2     0     0       0   89
# Bicycle                           0           1624     0     2       1   20
# ...                             ...            ...   ...   ...     ...  ...
# Vehicle                         132            212     6   534      12   49
# Vehicle registration plate       24             28     0     4       0    1
# Wheel                          1526           3390     0    35       2   89
# Window                            4              8     2    13       0    4
# Woman                            38             67     3    49      20  678
#
# DisplayName                 ...  Toy  Tree  Trousers  Truck  Vegetable  \
# DisplayName                 ...
# Animal                      ...   25   133         0      0          0
# Auto part                   ...   19   450         1    262          0
# Baked goods                 ...   26     0         0      0         29
# Ball (Object)               ...   31     5         2      0          0
# Bicycle                     ...    0   204         1      0          0
# ...                         ...  ...   ...       ...    ...        ...
# Vehicle                     ...   61  1026        20    100          0
# Vehicle registration plate  ...    0   198         0     23          0
# Wheel                       ...  142  2422        19   1057          0
# Window                      ...   47  6358         4    145          0
# Woman                       ...   35   775       279      5         56
#
# DisplayName                 Vehicle  Vehicle registration plate  Wheel  \
# DisplayName
# Animal                            6                           0     13
# Auto part                       452                         680   6956
# Baked goods                       0                           0      0
# Ball (Object)                    22                           0      4
# Bicycle                         132                          24   1526
# ...                             ...                         ...    ...
# Vehicle                           0                         245   4007
# Vehicle registration plate      245                           0   2803
# Wheel                          4007                        2803      0
# Window                          830                         853   5529
# Woman                           181                          15    344
#
# DisplayName                 Window  Woman
# DisplayName
# Animal                           3      5
# Auto part                     1789     49
# Baked goods                      0     83
# Ball (Object)                    0    145
# Bicycle                          4     38
# ...                            ...    ...
# Vehicle                        830    181
# Vehicle registration plate     853     15
# Wheel                         5529    344
# Window                           0     72
# Woman                           72      0
#
# [75 rows x 75 columns]

# %%
def create_classes_lists(cocc, n_lists, n_classes):
    classes_list = []
    for i in range(n_lists):
        init_class = np.random.choice(cocc.columns)
        all_classes = cocc[init_class].sample(n_classes - 1, weights = cocc[init_class]).index.tolist()
        all_classes.append(init_class) ## Add first class to the list
        classes_list.append(all_classes)
    return classes_list

# %%
classes_list = create_classes_lists(cocc, 30, 5)
classes_list
# Out:
# [['Snack', 'Person', 'Salad', 'Vegetable', 'Fast food'],
#  ['Vehicle', 'Human hair', 'Mammal', 'Auto part', 'Boat'],
#  ['Wheel', 'Bicycle wheel', 'Clothing', 'Sports equipment', 'Bicycle'],
#  ['Human leg', 'Human hand', 'Clothing', 'Human hair', 'Human arm'],
#  ['Human mouth', 'Mammal', 'Human head', 'Girl', 'Human hair'],
#  ['Plant', 'Window', 'Wheel', 'Person', 'Houseplant'],
#  ['Human hair', 'Human arm', 'Person', 'Sports equipment', 'Footwear'],
#  ['Food', 'Fish', 'Salad', 'Snack', 'Seafood'],
#  ['Human head', 'Sports equipment', 'Human body', 'Human hand', 'Girl'],
#  ['Footwear', 'Boy', 'Mammal', 'Sports equipment', 'Sports uniform'],
#  ['Human leg', 'Mammal', 'Woman', 'Tree', 'Boat'],
#  ['Wheel', 'Person', 'Clothing', 'Man', 'Fixed-wing aircraft'],
#  ['Plant', 'Clothing', 'Tire', 'Car', 'Land vehicle'],
#  ['Dog', 'Animal', 'Human face', 'Clothing', 'Carnivore'],
#  ['Clothing', 'Dog', 'Human hair', 'Mammal', 'Animal'],
#  ['Person', 'Human hair', 'Drink', 'Woman', 'Tableware'],
#  ['Tree', 'Mammal', 'Plant', 'Human ear', 'Bird'],
#  ['Food', 'Baked goods', 'Fast food', 'Dairy Product', 'Snack'],
#  ['Footwear', 'Land vehicle', 'Plant', 'Man', 'Carnivore'],
#  ['Car', 'Tire', 'Land vehicle', 'Tree', 'Vehicle'],
#  ['Snack', 'Fish', 'Food', 'Human hand', 'Seafood'],
#  ['Cat', 'Man', 'Clothing', 'Human face', 'Animal'],
#  ['Tree', 'Flower', 'Plant', 'Toy', 'Bird'],
#  ['Tree', 'Person', 'Human body', 'Mammal', 'Animal'],
#  ['Wheel', 'Tire', 'Person', 'Car', 'Land vehicle'],
#  ['Wheel', 'Land vehicle', 'Person', 'Tire', 'Truck'],
#  ['Human eye', 'Clothing', 'Human leg', 'Human hair', 'Human ear'],
#  ['Human hair', 'Human mouth', 'Human face', 'Human eye', 'Glasses'],
#  ['Mammal', 'Person', 'Vehicle', 'Woman', 'Boat'],
#  ['Human leg', 'Human hair', 'Footwear', 'Human head', 'Human body']]

# %%
# Delete all datasets from fiftyone
for name in fo.list_datasets() : 
    dataset = fo.load_dataset(name)
    dataset.delete()

# %%
class_list = openimages.get_classes(version='v6', dataset_dir=None)
classes_saved = []
num_trial = 0
i=1
while i <21:
    classes = classes_list[num_trial]
    print(classes)
    
    dataset = fo.zoo.load_zoo_dataset(
              "open-images-v6",
              split="validation",
              label_types=["detections"], 
            only_matching = True, 
            classes = classes,
            download_if_necessary  =  False,  
            dataset_dir = f"./fiftyone/open-images-v6/Raw/",
            max_samples = 1200,
            dataset_name = f'dataset_{num_trial}'
          )
    print(len(dataset))
    if len(dataset) == 1200:
        dataset.export(export_dir = f'./fiftyone/open-images-v6/Export/dataset_{i}/', 
               dataset_type = fo.types.VOCDetectionDataset)
        classes_saved.append(classes)
        i+=1
        print('i :', i)
    num_trial +=1
# Out:
# Downloading 'https://storage.googleapis.com/openimages/v5/class-descriptions-boxable.csv' to '/var/folders/yx/jwys6z8s7kdfb76vn404_81c0000gp/T/tmprmnb59r1/metadata/classes.csv'
# ['Snack', 'Person', 'Salad', 'Vegetable', 'Fast food']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [4.9s elapsed, 0s remaining, 251.5 samples/s]
# Dataset 'dataset_0' created
# 1200
#  100% |███████████████| 1200/1200 [16.5s elapsed, 0s remaining, 75.5 samples/s]
# i : 2
# ['Vehicle', 'Human hair', 'Mammal', 'Auto part', 'Boat']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [6.9s elapsed, 0s remaining, 168.3 samples/s]
# Dataset 'dataset_1' created
# 1200
#  100% |███████████████| 1200/1200 [14.6s elapsed, 0s remaining, 88.6 samples/s]
# i : 3
# ['Wheel', 'Bicycle wheel', 'Clothing', 'Sports equipment', 'Bicycle']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [8.4s elapsed, 0s remaining, 139.9 samples/s]
# Dataset 'dataset_2' created
# 1200
#  100% |███████████████| 1200/1200 [12.8s elapsed, 0s remaining, 96.6 samples/s]
# i : 4
# ['Human leg', 'Human hand', 'Clothing', 'Human hair', 'Human arm']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [14.6s elapsed, 0s remaining, 108.8 samples/s]
# Dataset 'dataset_3' created
# 1200
#  100% |███████████████| 1200/1200 [16.1s elapsed, 0s remaining, 80.9 samples/s]
# i : 5
# ['Human mouth', 'Mammal', 'Human head', 'Girl', 'Human hair']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [11.9s elapsed, 0s remaining, 122.1 samples/s]
# Dataset 'dataset_4' created
# 1200
#  100% |███████████████| 1200/1200 [14.8s elapsed, 0s remaining, 101.4 samples/s]
# i : 6
# ['Plant', 'Window', 'Wheel', 'Person', 'Houseplant']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [7.2s elapsed, 0s remaining, 195.9 samples/s]
# Dataset 'dataset_5' created
# 1200
#  100% |███████████████| 1200/1200 [12.5s elapsed, 0s remaining, 111.3 samples/s]
# i : 7
# ['Human hair', 'Human arm', 'Person', 'Sports equipment', 'Footwear']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [11.4s elapsed, 0s remaining, 123.4 samples/s]
# Dataset 'dataset_6' created
# 1200
#  100% |███████████████| 1200/1200 [14.0s elapsed, 0s remaining, 67.6 samples/s]
# i : 8
# ['Food', 'Fish', 'Salad', 'Snack', 'Seafood']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [7.8s elapsed, 0s remaining, 176.3 samples/s]
# Dataset 'dataset_7' created
# 1200
#  100% |███████████████| 1200/1200 [16.8s elapsed, 0s remaining, 72.1 samples/s]
# i : 9
# ['Human head', 'Sports equipment', 'Human body', 'Human hand', 'Girl']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [10.4s elapsed, 0s remaining, 122.7 samples/s]
# Dataset 'dataset_8' created
# 1200
#  100% |███████████████| 1200/1200 [13.1s elapsed, 0s remaining, 76.0 samples/s]
# i : 10
# ['Footwear', 'Boy', 'Mammal', 'Sports equipment', 'Sports uniform']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [10.5s elapsed, 0s remaining, 123.7 samples/s]
# Dataset 'dataset_9' created
# 1200
#  100% |███████████████| 1200/1200 [13.2s elapsed, 0s remaining, 69.1 samples/s]
# i : 11
# ['Human leg', 'Mammal', 'Woman', 'Tree', 'Boat']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [7.2s elapsed, 0s remaining, 157.1 samples/s]
# Dataset 'dataset_10' created
# 1200
#  100% |███████████████| 1200/1200 [11.3s elapsed, 0s remaining, 98.8 samples/s]
# i : 12
# ['Wheel', 'Person', 'Clothing', 'Man', 'Fixed-wing aircraft']
# Loading 'open-images-v6' split 'validation'
# Ignoring invalid classes ['Fixed-wing aircraft']
# You can view the available classes via `fiftyone.utils.openimages.get_classes()`
#  100% |███████████████| 1200/1200 [9.6s elapsed, 0s remaining, 124.4 samples/s]
# Dataset 'dataset_11' created
# 1200
#  100% |███████████████| 1200/1200 [12.7s elapsed, 0s remaining, 110.9 samples/s]
# i : 13
# ['Plant', 'Clothing', 'Tire', 'Car', 'Land vehicle']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [6.1s elapsed, 0s remaining, 181.7 samples/s]
# Dataset 'dataset_12' created
# 1200
#  100% |███████████████| 1200/1200 [11.2s elapsed, 0s remaining, 94.1 samples/s]
# i : 14
# ['Dog', 'Animal', 'Human face', 'Clothing', 'Carnivore']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [6.7s elapsed, 0s remaining, 146.1 samples/s]
# Dataset 'dataset_13' created
# 1200
#  100% |███████████████| 1200/1200 [11.2s elapsed, 0s remaining, 86.1 samples/s]
# i : 15
# ['Clothing', 'Dog', 'Human hair', 'Mammal', 'Animal']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [9.3s elapsed, 0s remaining, 133.0 samples/s]
# Dataset 'dataset_14' created
# 1200
#  100% |███████████████| 1200/1200 [12.2s elapsed, 0s remaining, 113.5 samples/s]
# i : 16
# ['Person', 'Human hair', 'Drink', 'Woman', 'Tableware']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [6.7s elapsed, 0s remaining, 207.9 samples/s]
# Dataset 'dataset_15' created
# 1200
#  100% |███████████████| 1200/1200 [11.0s elapsed, 0s remaining, 117.5 samples/s]
# i : 17
# ['Tree', 'Mammal', 'Plant', 'Human ear', 'Bird']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [6.8s elapsed, 0s remaining, 157.3 samples/s]
# Dataset 'dataset_16' created
# 1200
#  100% |███████████████| 1200/1200 [10.6s elapsed, 0s remaining, 96.2 samples/s]
# i : 18
# ['Food', 'Baked goods', 'Fast food', 'Dairy Product', 'Snack']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [7.0s elapsed, 0s remaining, 192.4 samples/s]
# Dataset 'dataset_17' created
# 1200
#  100% |███████████████| 1200/1200 [11.6s elapsed, 0s remaining, 112.1 samples/s]
# i : 19
# ['Footwear', 'Land vehicle', 'Plant', 'Man', 'Carnivore']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [6.1s elapsed, 0s remaining, 191.3 samples/s]
# Dataset 'dataset_18' created
# 1200
#  100% |███████████████| 1200/1200 [10.2s elapsed, 0s remaining, 95.7 samples/s]
# i : 20
# ['Car', 'Tire', 'Land vehicle', 'Tree', 'Vehicle']
# Loading 'open-images-v6' split 'validation'
#  100% |███████████████| 1200/1200 [9.8s elapsed, 0s remaining, 107.9 samples/s]
# Dataset 'dataset_19' created
# 1200
#  100% |███████████████| 1200/1200 [10.6s elapsed, 0s remaining, 104.1 samples/s]
# i : 21

# %%
classes_saved
# Out:
# [['Snack', 'Person', 'Salad', 'Vegetable', 'Fast food'],
#  ['Vehicle', 'Human hair', 'Mammal', 'Auto part', 'Boat'],
#  ['Wheel', 'Bicycle wheel', 'Clothing', 'Sports equipment', 'Bicycle'],
#  ['Human leg', 'Human hand', 'Clothing', 'Human hair', 'Human arm'],
#  ['Human mouth', 'Mammal', 'Human head', 'Girl', 'Human hair'],
#  ['Plant', 'Window', 'Wheel', 'Person', 'Houseplant'],
#  ['Human hair', 'Human arm', 'Person', 'Sports equipment', 'Footwear'],
#  ['Food', 'Fish', 'Salad', 'Snack', 'Seafood'],
#  ['Human head', 'Sports equipment', 'Human body', 'Human hand', 'Girl'],
#  ['Footwear', 'Boy', 'Mammal', 'Sports equipment', 'Sports uniform'],
#  ['Human leg', 'Mammal', 'Woman', 'Tree', 'Boat'],
#  ['Wheel', 'Person', 'Clothing', 'Man', 'Fixed-wing aircraft'],
#  ['Plant', 'Clothing', 'Tire', 'Car', 'Land vehicle'],
#  ['Dog', 'Animal', 'Human face', 'Clothing', 'Carnivore'],
#  ['Clothing', 'Dog', 'Human hair', 'Mammal', 'Animal'],
#  ['Person', 'Human hair', 'Drink', 'Woman', 'Tableware'],
#  ['Tree', 'Mammal', 'Plant', 'Human ear', 'Bird'],
#  ['Food', 'Baked goods', 'Fast food', 'Dairy Product', 'Snack'],
#  ['Footwear', 'Land vehicle', 'Plant', 'Man', 'Carnivore'],
#  ['Car', 'Tire', 'Land vehicle', 'Tree', 'Vehicle']]
